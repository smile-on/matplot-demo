# %% [markdown]
# <h1> XKCD style plots </h1>
# See [ XKCDify blog post](http://jakevdp.github.io/blog/2013/07/10/XKCD-plots-in-matplotlib/) for in deep dive.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def draw_sic_cos(ax):
    x = np.linspace(0, 10, 100)
    ax.plot(x, np.sin(x) * np.exp(-0.1 * (x - 5) ** 2), 'b', lw=1, label='damped sine')
    ax.plot(x, -np.cos(x) * np.exp(-0.1 * (x - 5) ** 2), 'r', lw=1, label='damped cosine')

    ax.set_title('check it out!')
    ax.set_xlabel('x label')
    ax.set_ylabel('y label')
    ax.legend(loc='lower right')

    ax.set_xlim(0, 10)
    ax.set_ylim(-1.0, 1.0)

# %%
np.random.seed(0)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

draw_sic_cos(ax)

# %% [markdown]
# Now with <b>XKCD style</b>!

# %% [markdown]
# You should get regular matplot similar to one on next cell.

# %%
from IPython.display import Image
Image('http://jakevdp.github.com/figures/mpl_version.png')

# %% [markdown]
# plt.xkcd() [magic function](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.xkcd.html)

# %%
np.random.seed(0)

with plt.xkcd():
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    draw_sic_cos(ax)

# %% [markdown]
# Compare to regular matplotlib plot above.
# You should get regular matplot similar to one on next cell.

# %%
Image('http://jakevdp.github.com/figures/xkcd_version.png')

# %%
fig = plt.figure(figsize=(10,8), tight_layout=True)
ax1 = fig.add_subplot(2, 1, 1)
draw_sic_cos(ax1)

with plt.xkcd(scale=1.5, length=100, randomness=3):
    ax2 = fig.add_subplot(2, 1, 2)
    draw_sic_cos(ax2)
# Out:
# /home/sl/env/py3dev/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
